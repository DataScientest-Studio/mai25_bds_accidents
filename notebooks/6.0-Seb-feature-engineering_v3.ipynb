# %%
import os
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency
path = os.path.join( "..", "data", "processed", "accidents_clean.csv")
accidents_clean = pd.read_csv(path)

# %%
# on enlèves les colonnes inutiles

accidents_clean = accidents_clean.drop(['lat', 'long','com'],axis=1)

# %%
accidents_clean.to_csv("../data/processed/accidents_preprocessed_v3.csv", index=False)
