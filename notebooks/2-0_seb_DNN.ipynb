# %%
####################################################################
# DNN sur version v2 du feature engineering (sans communes, avec dep, agg...)
####################################################################

import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.preprocessing import MultiLabelBinarizer
from category_encoders import TargetEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.combine import SMOTETomek
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasClassifier, KerasRegressor
import warnings
warnings.filterwarnings("ignore")

# === 1. Chargement et split
df = pd.read_csv("../data/processed/accidents_preprocessed_v2.csv")
X = df.drop(columns=["grav"])
y = df["grav"]

# Encodage y
le = LabelEncoder()
y_encoded = le.fit_transform(y)  # [1,2,3,4] -> [0,1,2,3]

X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, stratify=y_encoded, random_state=42)

# === 2. MultiLabelBinarizer sur 'equipements'
mlb = MultiLabelBinarizer()
equip_train = pd.DataFrame(mlb.fit_transform(X_train['equipements']),
                           columns=[f"eq_{str(c).replace(' ', '_')}" for c in mlb.classes_],
                           index=X_train.index)
equip_test = pd.DataFrame(mlb.transform(X_test['equipements']),
                          columns=[f"eq_{str(c).replace(' ', '_')}" for c in mlb.classes_],
                          index=X_test.index)

# Ajout aux datasets
X_train = pd.concat([X_train.drop(columns="equipements"), equip_train], axis=1)
X_test = pd.concat([X_test.drop(columns="equipements"), equip_test], axis=1)

# === 3. Encodage de "dep" avec TargetEncoder
te = TargetEncoder()
X_train["dep_encoded"] = te.fit_transform(X_train["dep"], y_train)
X_test["dep_encoded"] = te.transform(X_test["dep"])
X_train.drop(columns="dep", inplace=True)
X_test.drop(columns="dep", inplace=True)

# === 4. OneHotEncoder sur les autres colonnes
equip_cols = equip_train.columns.tolist()
cols_to_exclude = equip_cols + ['dep_encoded']
cols_to_ohe = [col for col in X_train.columns if col not in cols_to_exclude]

preprocessor = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown='ignore', sparse_output=False), cols_to_ohe)
], remainder='passthrough')

# === 5. Création du DNN
def create_model(input_dim):
    model = Sequential()
    model.add(Dense(64, activation='relu', input_shape=(input_dim,)))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(len(np.unique(y_train)), activation='softmax'))
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# On prépare les données pour le DNN
X_train_processed = preprocessor.fit_transform(X_train, y_train)
X_test_processed = preprocessor.transform(X_test)

# === 6. SMOTETomek sur données déjà encodées
rus = SMOTETomek(random_state=42)
X_resampled, y_resampled = rus.fit_resample(X_train_processed, y_train)

# === 7. Modèle Keras
input_dim = X_train_processed.shape[1]
model = create_model(input_dim)
model.fit(X_resampled, y_resampled, epochs=10, batch_size=128, validation_split=0.2, verbose=1)

# === 8. Prédiction
y_pred = np.argmax(model.predict(X_test_processed), axis=1)

# === 9. Inverse transform pour afficher y original [1–4]
y_test_labels = le.inverse_transform(y_test)
y_pred_labels = le.inverse_transform(y_pred)

# === 10. Résultats
print("📊 Classification report :")
print(classification_report(y_test_labels, y_pred_labels))

cm = confusion_matrix(y_test_labels, y_pred_labels)
plt.figure(figsize=(7, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=le.classes_,
            yticklabels=le.classes_)
plt.xlabel("Prédit")
plt.ylabel("Réel")
plt.title("Matrice de confusion")
plt.show()
# Out:
# Epoch 1/10
# 4524/4524 ━━━━━━━━━━━━━━━━━━━━ 3s 506us/step - accuracy: 0.6052 - loss: 0.9148 - val_accuracy: 0.1057 - val_loss: 1.6611
# Epoch 2/10
# 4524/4524 ━━━━━━━━━━━━━━━━━━━━ 2s 469us/step - accuracy: 0.6384 - loss: 0.8394 - val_accuracy: 0.0985 - val_loss: 1.7373
# Epoch 3/10
# 4524/4524 ━━━━━━━━━━━━━━━━━━━━ 2s 461us/step - accuracy: 0.6447 - loss: 0.8263 - val_accuracy: 0.1508 - val_loss: 1.7006
# Epoch 4/10
# 4524/4524 ━━━━━━━━━━━━━━━━━━━━ 2s 493us/step - accuracy: 0.6476 - loss: 0.8183 - val_accuracy: 0.1500 - val_loss: 1.5952
# Epoch 5/10
# 4524/4524 ━━━━━━━━━━━━━━━━━━━━ 2s 470us/step - accuracy: 0.6523 - loss: 0.8073 - val_accuracy: 0.1923 - val_loss: 1.5500
# Epoch 6/10
# 4524/4524 ━━━━━━━━━━━━━━━━━━━━ 2s 464us/step - accuracy: 0.6540 - loss: 0.8031 - val_accuracy: 0.2414 - val_loss: 1.3925
# Epoch 7/10
# 4524/4524 ━━━━━━━━━━━━━━━━━━━━ 2s 503us/step - accuracy: 0.6571 - loss: 0.7956 - val_accuracy: 0.3100 - val_loss: 1.2510
# Epoch 8/10
# 4524/4524 ━━━━━━━━━━━━━━━━━━━━ 2s 469us/step - accuracy: 0.6594 - loss: 0.7908 - val_accuracy: 0.3191 - val_loss: 1.2581
# Epoch 9/10
# 4524/4524 ━━━━━━━━━━━━━━━━━━━━ 2s 487us/step - accuracy: 0.6603 - loss: 0.7882 - val_accuracy: 0.2779 - val_loss: 1.3474
# Epoch 10/10
# 4524/4524 ━━━━━━━━━━━━━━━━━━━━ 2s 462us/step - accuracy: 0.6623 - loss: 0.7855 - val_accuracy: 0.2267 - val_loss: 1.4949
# 4833/4833 ━━━━━━━━━━━━━━━━━━━━ 1s 162us/step
# 📊 Classification report :
#               precision    recall  f1-score   support
#
#            1       0.75      0.78      0.77     65070
#            2       0.67      0.54      0.60     61671
#            3       0.41      0.61      0.49     23801
#            4       0.28      0.08      0.13      4110
#
#     accuracy                           0.64    154652
#    macro avg       0.53      0.50      0.50    154652
# weighted avg       0.65      0.64      0.64    154652

# %%
##################
# DNN avec SMOTETomek et ajustement de la probabilité de prédiction pour la classe 4 à 0.2 avec la version v2 du feature engineering
##################

import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.preprocessing import MultiLabelBinarizer
from category_encoders import TargetEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.combine import SMOTETomek
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasClassifier, KerasRegressor
import warnings
warnings.filterwarnings("ignore")

# === 1. Chargement et split
df = pd.read_csv("../data/processed/accidents_preprocessed_v2.csv")
X = df.drop(columns=["grav"])
y = df["grav"]

# Encodage y
le = LabelEncoder()
y_encoded = le.fit_transform(y)  # [1,2,3,4] -> [0,1,2,3]

X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, stratify=y_encoded, random_state=42)

# === 2. MultiLabelBinarizer sur 'equipements'
mlb = MultiLabelBinarizer()
equip_train = pd.DataFrame(mlb.fit_transform(X_train['equipements']),
                           columns=[f"eq_{str(c).replace(' ', '_')}" for c in mlb.classes_],
                           index=X_train.index)
equip_test = pd.DataFrame(mlb.transform(X_test['equipements']),
                          columns=[f"eq_{str(c).replace(' ', '_')}" for c in mlb.classes_],
                          index=X_test.index)

# Ajout aux datasets
X_train = pd.concat([X_train.drop(columns="equipements"), equip_train], axis=1)
X_test = pd.concat([X_test.drop(columns="equipements"), equip_test], axis=1)

# === 3. Encodage de "dep" avec TargetEncoder
te = TargetEncoder()
X_train["dep_encoded"] = te.fit_transform(X_train["dep"], y_train)
X_test["dep_encoded"] = te.transform(X_test["dep"])
X_train.drop(columns="dep", inplace=True)
X_test.drop(columns="dep", inplace=True)

# === 4. OneHotEncoder sur les autres colonnes
equip_cols = equip_train.columns.tolist()
cols_to_exclude = equip_cols + ['dep_encoded']
cols_to_ohe = [col for col in X_train.columns if col not in cols_to_exclude]

preprocessor = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown='ignore', sparse_output=False), cols_to_ohe)
], remainder='passthrough')

# === 5. Création du DNN
def create_model(input_dim):
    model = Sequential()
    model.add(Dense(64, activation='relu', input_shape=(input_dim,)))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(len(np.unique(y_train)), activation='softmax'))
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# On prépare les données pour le DNN
X_train_processed = preprocessor.fit_transform(X_train, y_train)
X_test_processed = preprocessor.transform(X_test)

# === 6. SMOTETomek sur données déjà encodées
rus = SMOTETomek(random_state=42)
X_resampled, y_resampled = rus.fit_resample(X_train_processed, y_train)

# === 7. Modèle Keras
input_dim = X_train_processed.shape[1]
model = create_model(input_dim)
model.fit(X_resampled, y_resampled, epochs=10, batch_size=128, validation_split=0.2, verbose=1)

# === 8. Prédiction

seuil_classe_4 = 0.2
classe_4_idx = 3  
y_proba = model.predict(X_test_processed)  # shape: (n_samples, n_classes)
y_pred = np.argmax(y_proba, axis=1)
y_pred[y_proba[:, classe_4_idx] >= seuil_classe_4] = classe_4_idx



# === 9. Inverse transform pour afficher y original [1–4]
y_test_labels = le.inverse_transform(y_test)
y_pred_labels = le.inverse_transform(y_pred)

# === 10. Résultats
print("📊 Classification report :")
print(classification_report(y_test_labels, y_pred_labels))

cm = confusion_matrix(y_test_labels, y_pred_labels)
plt.figure(figsize=(7, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=le.classes_,
            yticklabels=le.classes_)
plt.xlabel("Prédit")
plt.ylabel("Réel")
plt.title("Matrice de confusion")
plt.show()
# Out:
# Epoch 1/10
# 4524/4524 ━━━━━━━━━━━━━━━━━━━━ 2s 463us/step - accuracy: 0.5985 - loss: 0.9239 - val_accuracy: 0.1540 - val_loss: 1.5461
# Epoch 2/10
# 4524/4524 ━━━━━━━━━━━━━━━━━━━━ 2s 436us/step - accuracy: 0.6360 - loss: 0.8451 - val_accuracy: 0.1594 - val_loss: 1.5019
# Epoch 3/10
# 4524/4524 ━━━━━━━━━━━━━━━━━━━━ 2s 465us/step - accuracy: 0.6406 - loss: 0.8348 - val_accuracy: 0.1683 - val_loss: 1.5563
# Epoch 4/10
# 4524/4524 ━━━━━━━━━━━━━━━━━━━━ 2s 472us/step - accuracy: 0.6460 - loss: 0.8225 - val_accuracy: 0.0818 - val_loss: 1.9081
# Epoch 5/10
# 4524/4524 ━━━━━━━━━━━━━━━━━━━━ 2s 437us/step - accuracy: 0.6476 - loss: 0.8180 - val_accuracy: 0.1756 - val_loss: 1.7555
# Epoch 6/10
# 4524/4524 ━━━━━━━━━━━━━━━━━━━━ 2s 445us/step - accuracy: 0.6512 - loss: 0.8104 - val_accuracy: 0.1997 - val_loss: 1.5060
# Epoch 7/10
# 4524/4524 ━━━━━━━━━━━━━━━━━━━━ 2s 444us/step - accuracy: 0.6533 - loss: 0.8045 - val_accuracy: 0.1664 - val_loss: 1.5960
# Epoch 8/10
# 4524/4524 ━━━━━━━━━━━━━━━━━━━━ 2s 436us/step - accuracy: 0.6553 - loss: 0.8008 - val_accuracy: 0.1812 - val_loss: 1.5901
# Epoch 9/10
# 4524/4524 ━━━━━━━━━━━━━━━━━━━━ 2s 442us/step - accuracy: 0.6569 - loss: 0.7959 - val_accuracy: 0.2490 - val_loss: 1.4235
# Epoch 10/10
# 4524/4524 ━━━━━━━━━━━━━━━━━━━━ 2s 447us/step - accuracy: 0.6584 - loss: 0.7927 - val_accuracy: 0.2221 - val_loss: 1.5022
# 4833/4833 ━━━━━━━━━━━━━━━━━━━━ 1s 175us/step
# 📊 Classification report :
#               precision    recall  f1-score   support
#
#            1       0.78      0.73      0.75     65070
#            2       0.67      0.49      0.56     61671
#            3       0.35      0.61      0.45     23801
#            4       0.18      0.37      0.24      4110
#
#     accuracy                           0.60    154652
#    macro avg       0.50      0.55      0.50    154652
# weighted avg       0.65      0.60      0.62    154652

# %%
##################
# DNN avec undersampling et ajustement de la probabilité de prédiction pour la classe 4 à 0.2
# v2 du feature engineering (sans communes, avec dep, agg...) et one hot encoding sur toutes les colonnes (y compris dep)
# 2 couche de neurones en plus, 100 epochs 
##################

import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.preprocessing import MultiLabelBinarizer
from category_encoders import TargetEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.under_sampling import RandomUnderSampler
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasClassifier, KerasRegressor
import warnings
warnings.filterwarnings("ignore")

# === 1. Chargement et split
df = pd.read_csv("../data/processed/accidents_preprocessed_v2.csv")
X = df.drop(columns=["grav"])
y = df["grav"]

# Encodage y
le = LabelEncoder()
y_encoded = le.fit_transform(y)  # [1,2,3,4] -> [0,1,2,3]

X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, stratify=y_encoded, random_state=42)

# === 2. MultiLabelBinarizer sur 'equipements'
mlb = MultiLabelBinarizer()
equip_train = pd.DataFrame(mlb.fit_transform(X_train['equipements']),
                           columns=[f"eq_{str(c).replace(' ', '_')}" for c in mlb.classes_],
                           index=X_train.index)
equip_test = pd.DataFrame(mlb.transform(X_test['equipements']),
                          columns=[f"eq_{str(c).replace(' ', '_')}" for c in mlb.classes_],
                          index=X_test.index)

# Ajout aux datasets
X_train = pd.concat([X_train.drop(columns="equipements"), equip_train], axis=1)
X_test = pd.concat([X_test.drop(columns="equipements"), equip_test], axis=1)

# === 3. Encodage de "com" avec TargetEncoder
#te = TargetEncoder()
#X_train["com_encoded"] = te.fit_transform(X_train["com"], y_train)
#X_test["com_encoded"] = te.transform(X_test["com"])
#X_train.drop(columns="com", inplace=True)
#X_test.drop(columns="com", inplace=True)

# === 4. OneHotEncoder sur les autres colonnes
equip_cols = equip_train.columns.tolist()
cols_to_exclude = equip_cols + ['com_encoded']
cols_to_ohe = [col for col in X_train.columns if col not in cols_to_exclude]

preprocessor = ColumnTransformer([
    ('ohe', OneHotEncoder(handle_unknown='ignore', sparse_output=False), cols_to_ohe)
], remainder='passthrough')

# === 5. Création du DNN
def create_model(input_dim):
    model = Sequential()
    model.add(Dense(64, activation='relu', input_shape=(input_dim,)))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(16, activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(len(np.unique(y_train)), activation='softmax'))
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# On prépare les données pour le DNN
X_train_processed = preprocessor.fit_transform(X_train, y_train)
X_test_processed = preprocessor.transform(X_test)

# === 6. SMOTETomek sur données déjà encodées
rus = RandomUnderSampler(random_state=42)
X_resampled, y_resampled = rus.fit_resample(X_train_processed, y_train)

# === 7. Modèle Keras
input_dim = X_train_processed.shape[1]
model = create_model(input_dim)
model.fit(X_resampled, y_resampled, epochs=100, batch_size=128, validation_split=0.2, verbose=1)

# === 8. Prédiction

seuil_classe_4 = 0.2
classe_4_idx = 3  
y_proba = model.predict(X_test_processed)  # shape: (n_samples, n_classes)
y_pred = np.argmax(y_proba, axis=1)
y_pred[y_proba[:, classe_4_idx] >= seuil_classe_4] = classe_4_idx



# === 9. Inverse transform pour afficher y original [1–4]
y_test_labels = le.inverse_transform(y_test)
y_pred_labels = le.inverse_transform(y_pred)

# === 10. Résultats
print("📊 Classification report :")
print(classification_report(y_test_labels, y_pred_labels))

cm = confusion_matrix(y_test_labels, y_pred_labels)
plt.figure(figsize=(7, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=le.classes_,
            yticklabels=le.classes_)
plt.xlabel("Prédit")
plt.ylabel("Réel")
plt.title("Matrice de confusion")
plt.show()
# Out:
# Epoch 1/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 1s 837us/step - accuracy: 0.4489 - loss: 1.1863 - val_accuracy: 0.0000e+00 - val_loss: 2.1062
# Epoch 2/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - accuracy: 0.6087 - loss: 0.9093 - val_accuracy: 2.0274e-04 - val_loss: 2.1705
# Epoch 3/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - accuracy: 0.6219 - loss: 0.8844 - val_accuracy: 3.0411e-04 - val_loss: 2.1943
# Epoch 4/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step - accuracy: 0.6254 - loss: 0.8811 - val_accuracy: 0.0075 - val_loss: 2.1821
# Epoch 5/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - accuracy: 0.6323 - loss: 0.8605 - val_accuracy: 0.0177 - val_loss: 2.0818
# Epoch 6/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - accuracy: 0.6335 - loss: 0.8561 - val_accuracy: 0.0169 - val_loss: 2.1945
# Epoch 7/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step - accuracy: 0.6341 - loss: 0.8554 - val_accuracy: 0.0145 - val_loss: 2.2295
# Epoch 8/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step - accuracy: 0.6454 - loss: 0.8375 - val_accuracy: 0.0413 - val_loss: 2.0155
# Epoch 9/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - accuracy: 0.6453 - loss: 0.8303 - val_accuracy: 0.0181 - val_loss: 2.3999
# Epoch 10/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - accuracy: 0.6476 - loss: 0.8285 - val_accuracy: 0.0399 - val_loss: 2.1860
# Epoch 11/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - accuracy: 0.6555 - loss: 0.8170 - val_accuracy: 0.0660 - val_loss: 1.9334
# Epoch 12/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step - accuracy: 0.6577 - loss: 0.8103 - val_accuracy: 0.0958 - val_loss: 1.8735
# Epoch 13/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step - accuracy: 0.6620 - loss: 0.7965 - val_accuracy: 0.0696 - val_loss: 2.1051
# Epoch 14/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step - accuracy: 0.6626 - loss: 0.7951 - val_accuracy: 0.1008 - val_loss: 1.9668
# Epoch 15/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - accuracy: 0.6684 - loss: 0.7897 - val_accuracy: 0.0553 - val_loss: 2.0977
# Epoch 16/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step - accuracy: 0.6736 - loss: 0.7795 - val_accuracy: 0.1009 - val_loss: 2.0313
# Epoch 17/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step - accuracy: 0.6779 - loss: 0.7710 - val_accuracy: 0.0571 - val_loss: 2.3095
# Epoch 18/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - accuracy: 0.6790 - loss: 0.7603 - val_accuracy: 0.0287 - val_loss: 2.5837
# Epoch 19/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step - accuracy: 0.6839 - loss: 0.7564 - val_accuracy: 0.0660 - val_loss: 2.2039
# Epoch 20/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - accuracy: 0.6856 - loss: 0.7488 - val_accuracy: 0.0934 - val_loss: 2.2425
# Epoch 21/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - accuracy: 0.6896 - loss: 0.7419 - val_accuracy: 0.0918 - val_loss: 2.4069
# Epoch 22/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step - accuracy: 0.6864 - loss: 0.7475 - val_accuracy: 0.1033 - val_loss: 2.1604
# Epoch 23/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - accuracy: 0.7805 - loss: 0.5470 - val_accuracy: 0.1599 - val_loss: 2.9329
# Epoch 78/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - accuracy: 0.7801 - loss: 0.5498 - val_accuracy: 0.1605 - val_loss: 2.9669
# Epoch 79/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step - accuracy: 0.7791 - loss: 0.5469 - val_accuracy: 0.1263 - val_loss: 3.4422
# Epoch 80/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - accuracy: 0.7857 - loss: 0.5382 - val_accuracy: 0.1531 - val_loss: 3.1585
# Epoch 81/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step - accuracy: 0.7812 - loss: 0.5452 - val_accuracy: 0.1789 - val_loss: 2.9410
# Epoch 82/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - accuracy: 0.7814 - loss: 0.5385 - val_accuracy: 0.1740 - val_loss: 3.0276
# Epoch 83/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step - accuracy: 0.7857 - loss: 0.5305 - val_accuracy: 0.1542 - val_loss: 3.1805
# Epoch 84/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - accuracy: 0.7837 - loss: 0.5388 - val_accuracy: 0.1774 - val_loss: 3.0466
# Epoch 85/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - accuracy: 0.7860 - loss: 0.5320 - val_accuracy: 0.1773 - val_loss: 3.0602
# Epoch 86/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - accuracy: 0.7902 - loss: 0.5302 - val_accuracy: 0.1794 - val_loss: 3.1074
# Epoch 87/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - accuracy: 0.7878 - loss: 0.5362 - val_accuracy: 0.1786 - val_loss: 3.1426
# Epoch 88/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - accuracy: 0.7926 - loss: 0.5227 - val_accuracy: 0.1320 - val_loss: 3.4724
# Epoch 89/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step - accuracy: 0.7887 - loss: 0.5284 - val_accuracy: 0.1529 - val_loss: 3.2835
# Epoch 90/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - accuracy: 0.7953 - loss: 0.5177 - val_accuracy: 0.1728 - val_loss: 3.1805
# Epoch 91/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - accuracy: 0.7882 - loss: 0.5267 - val_accuracy: 0.1554 - val_loss: 3.2870
# Epoch 92/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - accuracy: 0.7900 - loss: 0.5201 - val_accuracy: 0.1883 - val_loss: 2.9891
# Epoch 93/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - accuracy: 0.7911 - loss: 0.5202 - val_accuracy: 0.1369 - val_loss: 3.4304
# Epoch 94/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - accuracy: 0.7858 - loss: 0.5257 - val_accuracy: 0.1182 - val_loss: 3.6434
# Epoch 95/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - accuracy: 0.7900 - loss: 0.5245 - val_accuracy: 0.1190 - val_loss: 3.7011
# Epoch 96/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - accuracy: 0.7936 - loss: 0.5187 - val_accuracy: 0.1700 - val_loss: 3.2189
# Epoch 97/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - accuracy: 0.7969 - loss: 0.5097 - val_accuracy: 0.1558 - val_loss: 3.5256
# Epoch 98/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step - accuracy: 0.7999 - loss: 0.5093 - val_accuracy: 0.2003 - val_loss: 3.0813
# Epoch 99/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step - accuracy: 0.7981 - loss: 0.5082 - val_accuracy: 0.1473 - val_loss: 3.4577
# Epoch 100/100
# 309/309 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - accuracy: 0.7917 - loss: 0.5137 - val_accuracy: 0.1394 - val_loss: 3.6447
# 4833/4833 ━━━━━━━━━━━━━━━━━━━━ 1s 181us/step
# 📊 Classification report :
#               precision    recall  f1-score   support
#
#            1       0.71      0.72      0.72     65070
#            2       0.61      0.46      0.52     61671
#            3       0.35      0.51      0.42     23801
#            4       0.12      0.24      0.16      4110
#
#     accuracy                           0.57    154652
#    macro avg       0.45      0.48      0.45    154652
# weighted avg       0.60      0.57      0.58    154652
